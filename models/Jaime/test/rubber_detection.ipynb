# %% [markdown]
# # Detección de rubber strips — YOLOv9
#
# Pipeline:
# 1. Carga YOLOv9 (`michelin_v2`)
# 2. Inferencia filtrando solo `rubber_strip` (clase 2)
# 3. Compara predicciones con ground truth de `new_samples`
# 4. Métricas reales: IoU bbox, Precision, Recall
# 5. Guarda visualizaciones en `outputs/figures/rubber_detection/`
#
# **Colores:** verde = ground truth · amarillo = predicción

# %% [markdown]
# ## 1. Cargar modelo

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from ultralytics import YOLO

WEIGHTS          = "runs/data/runs/michelin_v2/weights/best.pt"
RUBBER_CLASS     = 2
CONF_THR         = 0.25
IOU_THR          = 0.5    # umbral para considerar un match TP
MAX_BOX_RATIO    = 0.15   # descarta predicciones cuya área supere el 15% de la imagen

COLOR_GT   = (0, 220, 80)    # verde  — ground truth
COLOR_PRED = (255, 220, 0)   # amarillo — predicción

model = YOLO(WEIGHTS)
print(f"Modelo cargado: {WEIGHTS}")
# Out:
# Modelo cargado: runs/data/runs/michelin_v2/weights/best.pt

# %% [markdown]
# ## 2. Helpers

# %%
def load_gt_rubber(label_path, img_w, img_h):
    boxes = []
    if not Path(label_path).exists():
        return boxes
    for line in Path(label_path).read_text().splitlines():
        parts = line.strip().split()
        if not parts or int(parts[0]) != RUBBER_CLASS:
            continue
        cx, cy, w, h = map(float, parts[1:])
        x1 = (cx - w / 2) * img_w
        y1 = (cy - h / 2) * img_h
        x2 = (cx + w / 2) * img_w
        y2 = (cy + h / 2) * img_h
        boxes.append([x1, y1, x2, y2])
    return boxes


def bbox_iou(a, b):
    ix1 = max(a[0], b[0]);  iy1 = max(a[1], b[1])
    ix2 = min(a[2], b[2]);  iy2 = min(a[3], b[3])
    inter  = max(0, ix2 - ix1) * max(0, iy2 - iy1)
    area_a = (a[2]-a[0]) * (a[3]-a[1])
    area_b = (b[2]-b[0]) * (b[3]-b[1])
    union  = area_a + area_b - inter
    return inter / union if union > 0 else 0.0


def match_predictions(gt_boxes, pred_boxes, iou_thr=IOU_THR):
    matched_gt   = set()
    matched_pred = set()
    tp_ious = []
    for pi, pred in enumerate(pred_boxes):
        best_iou, best_gi = 0.0, -1
        for gi, gt in enumerate(gt_boxes):
            if gi in matched_gt:
                continue
            iou = bbox_iou(pred, gt)
            if iou > best_iou:
                best_iou, best_gi = iou, gi
        if best_iou >= iou_thr:
            tp_ious.append(best_iou)
            matched_gt.add(best_gi)
            matched_pred.add(pi)
    n_fp = len(pred_boxes) - len(matched_pred)
    n_fn = len(gt_boxes)   - len(matched_gt)
    return tp_ious, n_fp, n_fn


print("Helpers listos.")
# Out:
# Helpers listos.

# %% [markdown]
# ## 3. Test sobre una imagen

# %%
DATA_ROOT = Path("../data/new_samples")

sample_img = sorted((DATA_ROOT / "train" / "images").glob("*.jpg"))[0]
sample_lbl = DATA_ROOT / "train" / "labels" / (sample_img.stem + ".txt")

img_bgr = cv2.imread(str(sample_img))
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
H, W    = img_rgb.shape[:2]

gt_boxes = load_gt_rubber(sample_lbl, W, H)
preds    = model(img_bgr, verbose=False, conf=CONF_THR)[0]

raw_preds  = [(b.xyxy[0], float(b.conf[0])) for b in preds.boxes if int(b.cls[0]) == RUBBER_CLASS]
raw_preds  = [p for p in raw_preds
              if (int(p[0][2])-int(p[0][0])) * (int(p[0][3])-int(p[0][1])) / (H * W) <= MAX_BOX_RATIO]
pred_boxes = [[*map(int, p[0])] for p in raw_preds]
pred_confs = [p[1] for p in raw_preds]

tp_ious, n_fp, n_fn = match_predictions(gt_boxes, pred_boxes)
print(f"GT rubber strips: {len(gt_boxes)}  |  Predichos: {len(pred_boxes)}")
print(f"TP: {len(tp_ious)}  FP: {n_fp}  FN: {n_fn}")
if tp_ious:
    print(f"IoU medio (TP): {np.mean(tp_ious):.3f}")

overlay = img_rgb.copy()
for box in gt_boxes:
    x1, y1, x2, y2 = map(int, box)
    cv2.rectangle(overlay, (x1, y1), (x2, y2), COLOR_GT, 3)
    cv2.putText(overlay, "GT", (x1, max(y1-8, 12)), cv2.FONT_HERSHEY_SIMPLEX, 0.7, COLOR_GT, 2)
for box, conf in zip(pred_boxes, pred_confs):
    x1, y1, x2, y2 = box
    cv2.rectangle(overlay, (x1, y1), (x2, y2), COLOR_PRED, 2)
    cv2.putText(overlay, f"pred {conf:.2f}", (x1, y2+18), cv2.FONT_HERSHEY_SIMPLEX, 0.6, COLOR_PRED, 2)

fig, ax = plt.subplots(1, 1, figsize=(8, 8))
ax.imshow(overlay)
ax.set_title("GT (verde) vs Pred (amarillo)")
ax.axis("off")
fig.suptitle(sample_img.name, fontsize=11, fontweight="bold")
plt.tight_layout()
plt.show()
# Out:
# GT rubber strips: 2  |  Predichos: 2
# TP: 0  FP: 2  FN: 2

# %% [markdown]
# ## 4. Evaluación sobre todo el dataset (train + valid)

# %%
DATA_ROOT = Path("../data/new_samples")

all_imgs = [
    (img, DATA_ROOT / "train" / "labels" / (img.stem + ".txt"))
    for img in sorted((DATA_ROOT / "train" / "images").glob("*.jpg"))
] + [
    (img, DATA_ROOT / "valid" / "labels" / (img.stem + ".txt"))
    for img in sorted((DATA_ROOT / "valid" / "images").glob("*.jpg"))
]
print(f"Total imágenes: {len(all_imgs)}")

total_tp, total_fp, total_fn = 0, 0, 0
all_tp_ious = []
per_image   = []

for img_path, lbl_path in all_imgs:
    img_bgr    = cv2.imread(str(img_path))
    H, W       = img_bgr.shape[:2]
    gt_boxes   = load_gt_rubber(lbl_path, W, H)
    preds      = model(img_bgr, verbose=False, conf=CONF_THR)[0]
    pred_boxes = [[*map(int, b.xyxy[0])] for b in preds.boxes
                  if int(b.cls[0]) == RUBBER_CLASS
                  and (int(b.xyxy[0][2])-int(b.xyxy[0][0])) * (int(b.xyxy[0][3])-int(b.xyxy[0][1])) / (H * W) <= MAX_BOX_RATIO]

    tp_ious, n_fp, n_fn = match_predictions(gt_boxes, pred_boxes)
    total_tp += len(tp_ious)
    total_fp += n_fp
    total_fn += n_fn
    all_tp_ious.extend(tp_ious)

    per_image.append({
        "name":     img_path.name,
        "gt":       len(gt_boxes),
        "pred":     len(pred_boxes),
        "tp":       len(tp_ious),
        "fp":       n_fp,
        "fn":       n_fn,
        "iou_mean": np.mean(tp_ious) if tp_ious else None,
    })

precision = total_tp / (total_tp + total_fp) if (total_tp + total_fp) > 0 else 0
recall    = total_tp / (total_tp + total_fn) if (total_tp + total_fn) > 0 else 0
f1        = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0

print(f"\n{'='*55}")
print(f"TP: {total_tp}  FP: {total_fp}  FN: {total_fn}")
print(f"Precision: {precision:.3f}")
print(f"Recall:    {recall:.3f}")
print(f"F1:        {f1:.3f}")
if all_tp_ious:
    print(f"IoU medio (TP): {np.mean(all_tp_ious):.3f}")

print(f"\n{'Imagen':<50} {'GT':>4} {'Pred':>5} {'TP':>4} {'FP':>4} {'FN':>4} {'IoU':>6}")
print("-" * 80)
for r in per_image:
    iou_str = f"{r['iou_mean']:.3f}" if r["iou_mean"] is not None else "  — "
    print(f"{r['name']:<50} {r['gt']:>4} {r['pred']:>5} {r['tp']:>4} {r['fp']:>4} {r['fn']:>4} {iou_str:>6}")
# Out:
# Total imágenes: 22
#
# =======================================================
# TP: 0  FP: 21  FN: 44
# Precision: 0.000
# Recall:    0.000
# F1:        0.000
#
# Imagen                                               GT  Pred   TP   FP   FN    IoU
# --------------------------------------------------------------------------------
# multimedia_01_jpg.rf.VXa1Uc1sODZfNRA5yypB.jpg         2     2    0    2    2     —
# multimedia_02_jpg.rf.Oj3RZ61LrtxiLIH6Q2qV.jpg         2     0    0    0    2     —
# multimedia_04_jpg.rf.MGHdsSXWAqCvpoTV9eEz.jpg         2     0    0    0    2     —
# multimedia_05_jpg.rf.UmwCstSbCbadDh62kdyj.jpg         2     3    0    3    2     —
# multimedia_07_jpg.rf.rzxqe1IXC3fkfze6QTtc.jpg         2     1    0    1    2     —
# multimedia_08_jpg.rf.Z7rzyNv5BaX4JsejH44T.jpg         2     1    0    1    2     —
# multimedia_09_jpg.rf.4yp5FkHpPSDiJCr0gnE6.jpg         2     0    0    0    2     —
# multimedia_10_jpg.rf.wxfQCr6OUG88R64iwuod.jpg         2     0    0    0    2     —
# multimedia_11_jpg.rf.U2X6VMrXEcfhMHZ1Plqu.jpg         2     0    0    0    2     —
# multimedia_12_jpg.rf.WIFwzmQEF0m39hjVPpFX.jpg         2     1    0    1    2     —
# multimedia_13_jpg.rf.QuEMlo9c5B0h2k2x4EHV.jpg         2     0    0    0    2     —
# multimedia_14_jpg.rf.5K08koBZf3fIiEVmdeMi.jpg         2     2    0    2    2     —
# multimedia_15_jpg.rf.kAXKjoyWMSQKOf9HZUpK.jpg         2     0    0    0    2     —
# multimedia_17_jpg.rf.IoW5mGwsne4SNcdyVX5n.jpg         2     2    0    2    2     —
# multimedia_18_jpg.rf.RPlmEHwUc7Cvn9uB5HtT.jpg         2     1    0    1    2     —
# multimedia_19_jpg.rf.E4584uN98ycMuO1gGNyU.jpg         2     1    0    1    2     —
# multimedia_20_jpg.rf.yP6m3FwgbHY78EVLNYeB.jpg         2     1    0    1    2     —
# multimedia_21_jpg.rf.osecPtK6ne3MyNpzCptN.jpg         2     0    0    0    2     —
# multimedia_03_jpg.rf.emhFvRBdprR06GtcFXk5.jpg         2     2    0    2    2     —
# multimedia_06_jpg.rf.ectK1L2SxmAd7ztdtkSQ.jpg         2     3    0    3    2     —
# multimedia_16_jpg.rf.j1h7FQ1QZa0L3w4fm69t.jpg         2     1    0    1    2     —
# multimedia_22_jpg.rf.Cl7KoaupjYYnOBYhuT6a.jpg         2     0    0    0    2     —

# %% [markdown]
# ## 5. Guardar visualizaciones

# %%
OUT_DIR = Path("../outputs/figures/rubber_detection")
OUT_DIR.mkdir(parents=True, exist_ok=True)

for img_path, lbl_path in all_imgs:
    img_bgr    = cv2.imread(str(img_path))
    img_rgb    = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    H, W       = img_rgb.shape[:2]
    gt_boxes   = load_gt_rubber(lbl_path, W, H)
    preds      = model(img_bgr, verbose=False, conf=CONF_THR)[0]

    raw_preds  = [(b.xyxy[0], float(b.conf[0])) for b in preds.boxes if int(b.cls[0]) == RUBBER_CLASS]
    raw_preds  = [p for p in raw_preds
                  if (int(p[0][2])-int(p[0][0])) * (int(p[0][3])-int(p[0][1])) / (H * W) <= MAX_BOX_RATIO]
    pred_boxes = [[*map(int, p[0])] for p in raw_preds]
    pred_confs = [p[1] for p in raw_preds]

    tp_ious, n_fp, n_fn = match_predictions(gt_boxes, pred_boxes)

    overlay = img_rgb.copy()
    for box in gt_boxes:
        x1, y1, x2, y2 = map(int, box)
        cv2.rectangle(overlay, (x1, y1), (x2, y2), COLOR_GT, 3)
        cv2.putText(overlay, "GT", (x1, max(y1-8, 12)), cv2.FONT_HERSHEY_SIMPLEX, 0.65, COLOR_GT, 2)
    for box, conf in zip(pred_boxes, pred_confs):
        x1, y1, x2, y2 = box
        cv2.rectangle(overlay, (x1, y1), (x2, y2), COLOR_PRED, 2)
        cv2.putText(overlay, f"pred {conf:.2f}", (x1, y2+18), cv2.FONT_HERSHEY_SIMPLEX, 0.6, COLOR_PRED, 2)

    iou_str  = f"IoU={np.mean(tp_ious):.3f}" if tp_ious else "IoU=nulo"
    subtitle = f"GT={len(gt_boxes)}  Pred={len(pred_boxes)}  TP={len(tp_ious)}  FP={n_fp}  FN={n_fn}  {iou_str}"

    fig, ax = plt.subplots(1, 1, figsize=(8, 8))
    ax.imshow(overlay)
    ax.set_title("GT (verde) vs Pred (amarillo)")
    ax.axis("off")
    fig.suptitle(f"{img_path.name}\n{subtitle}", fontsize=10, fontweight="bold")
    plt.tight_layout()

    plt.savefig(OUT_DIR / f"{img_path.stem}.jpg", dpi=100, bbox_inches="tight")
    plt.close()
    print(f"  {img_path.name} → {subtitle}")

print(f"\nFiguras guardadas en: {OUT_DIR.resolve()}")
# Out:
#   multimedia_01_jpg.rf.VXa1Uc1sODZfNRA5yypB.jpg → GT=2  Pred=2  TP=0  FP=2  FN=2  IoU=nulo
#   multimedia_02_jpg.rf.Oj3RZ61LrtxiLIH6Q2qV.jpg → GT=2  Pred=0  TP=0  FP=0  FN=2  IoU=nulo
#   multimedia_04_jpg.rf.MGHdsSXWAqCvpoTV9eEz.jpg → GT=2  Pred=0  TP=0  FP=0  FN=2  IoU=nulo
#   multimedia_05_jpg.rf.UmwCstSbCbadDh62kdyj.jpg → GT=2  Pred=3  TP=0  FP=3  FN=2  IoU=nulo
#   multimedia_07_jpg.rf.rzxqe1IXC3fkfze6QTtc.jpg → GT=2  Pred=1  TP=0  FP=1  FN=2  IoU=nulo
#   multimedia_08_jpg.rf.Z7rzyNv5BaX4JsejH44T.jpg → GT=2  Pred=1  TP=0  FP=1  FN=2  IoU=nulo
#   multimedia_09_jpg.rf.4yp5FkHpPSDiJCr0gnE6.jpg → GT=2  Pred=0  TP=0  FP=0  FN=2  IoU=nulo
#   multimedia_10_jpg.rf.wxfQCr6OUG88R64iwuod.jpg → GT=2  Pred=0  TP=0  FP=0  FN=2  IoU=nulo
#   multimedia_11_jpg.rf.U2X6VMrXEcfhMHZ1Plqu.jpg → GT=2  Pred=0  TP=0  FP=0  FN=2  IoU=nulo
#   multimedia_12_jpg.rf.WIFwzmQEF0m39hjVPpFX.jpg → GT=2  Pred=1  TP=0  FP=1  FN=2  IoU=nulo
#   multimedia_13_jpg.rf.QuEMlo9c5B0h2k2x4EHV.jpg → GT=2  Pred=0  TP=0  FP=0  FN=2  IoU=nulo
#   multimedia_14_jpg.rf.5K08koBZf3fIiEVmdeMi.jpg → GT=2  Pred=2  TP=0  FP=2  FN=2  IoU=nulo
#   multimedia_15_jpg.rf.kAXKjoyWMSQKOf9HZUpK.jpg → GT=2  Pred=0  TP=0  FP=0  FN=2  IoU=nulo
#   multimedia_17_jpg.rf.IoW5mGwsne4SNcdyVX5n.jpg → GT=2  Pred=2  TP=0  FP=2  FN=2  IoU=nulo
#   multimedia_18_jpg.rf.RPlmEHwUc7Cvn9uB5HtT.jpg → GT=2  Pred=1  TP=0  FP=1  FN=2  IoU=nulo
#   multimedia_19_jpg.rf.E4584uN98ycMuO1gGNyU.jpg → GT=2  Pred=1  TP=0  FP=1  FN=2  IoU=nulo
#   multimedia_20_jpg.rf.yP6m3FwgbHY78EVLNYeB.jpg → GT=2  Pred=1  TP=0  FP=1  FN=2  IoU=nulo
#   multimedia_21_jpg.rf.osecPtK6ne3MyNpzCptN.jpg → GT=2  Pred=0  TP=0  FP=0  FN=2  IoU=nulo
#   multimedia_03_jpg.rf.emhFvRBdprR06GtcFXk5.jpg → GT=2  Pred=2  TP=0  FP=2  FN=2  IoU=nulo
#   multimedia_06_jpg.rf.ectK1L2SxmAd7ztdtkSQ.jpg → GT=2  Pred=3  TP=0  FP=3  FN=2  IoU=nulo
#   multimedia_16_jpg.rf.j1h7FQ1QZa0L3w4fm69t.jpg → GT=2  Pred=1  TP=0  FP=1  FN=2  IoU=nulo
#   multimedia_22_jpg.rf.Cl7KoaupjYYnOBYhuT6a.jpg → GT=2  Pred=0  TP=0  FP=0  FN=2  IoU=nulo
#
# Figuras guardadas en: C:\Users\jaime\Proyectos\VA_RetoMichelin\models\Jaime\outputs\figures\rubber_detection
